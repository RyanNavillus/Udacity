# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %%
print(len(words))
print(words[:40])
print(len(train_words))
print(train_words[:40])
print(len(excluded_words))
print(excluded_words[:40])
print(counts["to"])
# Out:
# 16680599
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to']
# 4627106
# [5233, 3133, 58, 155, 10571, 27349, 15067, 58112, 854, 3580, 10712, 214, 1324, 454, 2731, 371, 539, 2757, 7088, 247, 5233, 1052, 44611, 186, 5233, 1134, 8983, 279, 4147, 6437, 153, 5233, 344, 4860, 6753, 7573, 11064, 7088, 5948, 4861]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-7696f9d4c7a9> in <module>()
#       3 print(len(train_words))
#       4 print(train_words[:40])
# ----> 5 print(len(excluded_words))
#       6 print(excluded_words[:40])
#       7 print(counts["to"])
#
# NameError: name 'excluded_words' is not defined

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1,window_size+1)
    start = idx-r if idx-r >= 0 else 0
    end = idx+r+1 if idx+r+1 <= len(words) else len(words)
    targets = []
    for index in range(start, end):
        if index == idx:
            continue
        targets.append(words[index])
    
    return targets

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)
# Out:
# WARNING:tensorflow:From C:\Users\Ryan Sullivan\AppData\Local\conda\conda\envs\jupyter\lib\site-packages\tensorflow\python\ops\nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-2aa168c49a56>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# A subdirectory or file checkpoints already exists.

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6016 0.0436 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5985 0.0396 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4735 0.0397 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5443 0.0396 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4541 0.0396 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4652 0.0396 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5139 0.0397 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5277 0.0396 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4220 0.0400 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3912 0.0401 sec/batch
# Nearest to also: agreements, harel, caution, alla, newall, paragraph, tilapia, thereby,
# Nearest to state: kmaq, nathalie, vers, nurseries, inverting, marquette, immunosuppression, krieg,
# Nearest to s: glycoprotein, moltke, bhaktivedanta, government, gerald, vives, country, mayer,
# Nearest to have: ethyl, carnac, shipboard, antoni, lollapalooza, scavenge, litovsk, freezer,
# Nearest to had: boutique, mike, istria, pippin, philosophic, eesti, moody, interfered,
# Nearest to if: eduard, lg, materia, huston, buckley, overwork, arraignment, panama,
# Nearest to his: industries, disruption, fadlan, submerged, nutrients, husayn, reeve, curtis,
# Nearest to between: camulodunum, obliquely, aorta, squadrons, minestrone, directorate, leukemia, purpose,
# Nearest to nobel: linz, renault, buke, redistricting, restricts, mems, gracchi, fringes,
# Nearest to account: trillion, insulating, shuja, regents, malagasy, cra, clerics, nanomachines,
# Nearest to notes: bighorn, ibis, poses, dough, primigenius, legitimize, vatsetis, obed,
# Nearest to hit: flavors, midseason, adversarial, ideological, eulemur, mcp, issuing, melvin,
# Nearest to ocean: odp, degrades, sockets, doctoral, banu, megiddo, piet, curious,
# Nearest to additional: fanny, mold, bounced, rigel, densities, rankings, phrased, synaptic,
# Nearest to governor: fabric, encyclopedia, rhoda, dwindled, intensive, guernica, ended, hydrosphere,
# Nearest to proposed: bijections, companies, shearwater, qurra, thicknesses, lansing, unobstructed, sw,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4516 0.0414 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3336 0.0400 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2884 0.0398 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.1954 0.0396 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1624 0.0396 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1373 0.0399 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0655 0.0398 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0664 0.0397 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0144 0.0397 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0113 0.0396 sec/batch
# Nearest to also: agreements, caution, population, thereby, learning, book, harel, paragraph,
# Nearest to state: kmaq, nathalie, nurseries, approaches, vers, modernist, pervasive, higher,
# Nearest to s: government, gerald, company, glycoprotein, country, condition, bhaktivedanta, asked,
# Nearest to have: ethyl, v, reservoir, carnac, parties, disrupted, extreme, database,
# Nearest to had: mike, still, pippin, boutique, istria, factors, captivity, arm,
# Nearest to if: decide, lg, eduard, panama, is, spent, arraignment, materia,
# Nearest to his: disruption, industries, basic, fadlan, does, repeated, evolved, dynasty,
# Nearest to between: obliquely, camulodunum, south, aorta, squadrons, albeit, permits, leukemia,
# Nearest to nobel: fringes, gracchi, linz, restricts, danson, buke, redistricting, blend,
# Nearest to account: trillion, insulating, felt, famously, though, normal, order, steve,
# Nearest to notes: poses, bighorn, orthogonal, ibis, interpretation, entheogenic, dough, govern,
# Nearest to hit: flavors, midseason, adversarial, ideological, fewest, balanced, inexpensive, issuing,
# Nearest to ocean: odp, degrades, sockets, banu, curious, triune, piet, alveoli,
# Nearest to additional: mold, rigel, phrased, season, bounced, rankings, compressed, animation,
# Nearest to governor: encyclopedia, fabric, ended, films, received, intensive, current, turn,
# Nearest to proposed: companies, bijections, shearwater, unobstructed, pronoun, thicknesses, pressed, guinness,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9543 0.0413 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9437 0.0395 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8799 0.0397 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8893 0.0397 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8280 0.0396 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8227 0.0397 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7807 0.0398 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7949 0.0397 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7832 0.0396 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7684 0.0397 sec/batch
# Nearest to also: agreements, caution, paragraph, wholly, learning, harel, population, book,
# Nearest to state: kmaq, nurseries, approaches, vers, pervasive, nathalie, modernist, equiv,
# Nearest to s: gerald, government, company, glycoprotein, mayer, moltke, country, releasing,
# Nearest to have: ethyl, reservoir, v, carnac, shipboard, opponents, rejecting, disrupted,
# Nearest to had: mike, pippin, philosophic, still, boutique, sizeable, istria, suffering,
# Nearest to if: decide, flourishing, buckley, overwork, arraignment, is, triplets, furnish,
# Nearest to his: disruption, industries, submerged, nutrients, evolved, repeated, wendy, absence,
# Nearest to between: obliquely, camulodunum, south, aorta, squadrons, leukemia, albeit, rural,
# Nearest to nobel: fringes, gracchi, linz, one, restricts, blend, redistricting, decoder,
# Nearest to account: trillion, insulating, felt, regents, steve, famously, clerics, malagasy,
# Nearest to notes: poses, ibis, orthogonal, bighorn, govern, preached, interpretation, entheogenic,
# Nearest to hit: flavors, ideological, adversarial, issuing, binary, midseason, inexpensive, fewest,
# Nearest to ocean: degrades, odp, sockets, banu, curious, piet, triune, nameplate,
# Nearest to additional: mold, rigel, phrased, rankings, season, bounced, compressed, fanny,
# Nearest to governor: encyclopedia, films, ended, fabric, dwindled, intensive, received, coalitions,
# Nearest to proposed: companies, bijections, unobstructed, qurra, shearwater, pronoun, pressed, thicknesses,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7783 0.0412 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7299 0.0396 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7264 0.0397 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7215 0.0399 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7510 0.0397 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6951 0.0397 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7452 0.0398 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7010 0.0397 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7089 0.0398 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6597 0.0397 sec/batch
# Nearest to also: agreements, caution, paragraph, harel, wholly, learning, thereby, alla,
# Nearest to state: kmaq, nurseries, pervasive, vers, nathalie, approaches, inverting, evictions,
# Nearest to s: gerald, company, mayer, glycoprotein, government, lenin, bhaktivedanta, vives,
# Nearest to have: carnac, ethyl, opponents, rejecting, antoni, reservoir, eton, christendom,
# Nearest to had: pippin, philosophic, mike, still, interfered, sizeable, boutique, bluebeard,
# Nearest to if: decide, arraignment, overwork, indistinguishable, materia, flourishing, carta, buckley,
# Nearest to his: disruption, submerged, graduated, industries, dynasty, nutrients, indictable, wendy,
# Nearest to between: obliquely, camulodunum, south, squadrons, aorta, leukemia, brethren, civilized,
# Nearest to nobel: one, linz, gracchi, hunsr, buke, fringes, trader, nine,
# Nearest to account: trillion, regents, insulating, steve, felt, clerics, famously, malagasy,
# Nearest to notes: poses, orthogonal, ibis, bighorn, govern, legitimize, entheogenic, dough,
# Nearest to hit: flavors, midseason, melvin, adversarial, ideological, inexpensive, nauru, baxter,
# Nearest to ocean: degrades, odp, sockets, piet, banu, doctoral, region, curious,
# Nearest to additional: mold, bounced, rigel, phrased, compressed, rankings, fanny, densities,
# Nearest to governor: ended, dwindled, encyclopedia, films, vanities, mara, received, tapering,
# Nearest to proposed: bijections, companies, qurra, unobstructed, clause, kundalini, thunderbolt, rep,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6353 0.0413 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6812 0.0398 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6299 0.0397 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6323 0.0397 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6133 0.0396 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6112 0.0397 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6050 0.0293 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5558 0.0397 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5334 0.0398 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5031 0.0396 sec/batch
# Nearest to also: agreements, caution, wholly, paragraph, harel, alla, learning, contented,
# Nearest to state: nurseries, kmaq, pervasive, evictions, vers, arnstadt, inverting, auger,
# Nearest to s: gerald, lenin, company, aradia, bhaktivedanta, glycoprotein, mayer, vives,
# Nearest to have: carnac, kierkegaard, opponents, ethyl, hellenistic, shipboard, eton, reservoir,
# Nearest to had: bluebeard, still, urals, pippin, arquette, suffering, istria, minting,
# Nearest to if: decide, indistinguishable, arraignment, overwork, deciphered, comparison, probability, abjads,
# Nearest to his: he, disruption, graduated, dynasty, submerged, respectfully, seedlings, indictable,
# Nearest to between: obliquely, south, camulodunum, squadrons, aorta, leukemia, minestrone, civilized,
# Nearest to nobel: one, linz, activist, nine, screenwriter, gracchi, laureate, comedienne,
# Nearest to account: trillion, regents, insulating, malagasy, clerics, felt, steve, famously,
# Nearest to notes: poses, orthogonal, bighorn, ibis, legitimize, xyz, melchior, entheogenic,
# Nearest to hit: flavors, midseason, melvin, adversarial, nauru, mcp, inexpensive, tom,
# Nearest to ocean: degrades, odp, region, banu, doctoral, nameplate, nborn, improvements,
# Nearest to additional: compressed, bounced, mold, rigel, tm, clock, rankings, phrased,
# Nearest to governor: ended, dwindled, encyclopedia, vanities, mara, films, received, tapering,
# Nearest to proposed: bijections, companies, qurra, clause, kundalini, unobstructed, pronoun, lansing,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.5226 0.0412 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5058 0.0396 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4997 0.0396 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5364 0.0396 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4741 0.0396 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4509 0.0397 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4581 0.0399 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3879 0.0399 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4222 0.0396 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4188 0.0395 sec/batch
# Nearest to also: agreements, caution, paragraph, alla, of, it, harel, newall,
# Nearest to state: nurseries, kmaq, evictions, executive, arnstadt, pervasive, vers, alo,
# Nearest to s: gerald, company, aradia, glycoprotein, bhaktivedanta, lenin, vives, mayer,
# Nearest to have: carnac, polygamist, hellenistic, kierkegaard, scavenge, opponents, hydrography, parties,
# Nearest to had: bluebeard, still, minting, urals, istria, arquette, cdm, outbursts,
# Nearest to if: decide, arraignment, indistinguishable, algebraically, overwork, probability, deciphered, follows,
# Nearest to his: he, mother, graduated, him, dynasty, respectfully, disruption, seedlings,
# Nearest to between: south, obliquely, camulodunum, squadrons, civilized, aorta, minestrone, divide,
# Nearest to nobel: linz, comedienne, screenwriter, activist, laureate, hunsr, gracchi, harry,
# Nearest to account: trillion, regents, insulating, malagasy, clerics, felt, piecemeal, though,
# Nearest to notes: poses, orthogonal, bighorn, melchior, legitimize, xyz, ibis, pertains,
# Nearest to hit: flavors, midseason, melvin, pal, inexpensive, tom, quarried, mcp,
# Nearest to ocean: degrades, region, odp, ft, banu, oceans, nameplate, nborn,
# Nearest to additional: compressed, bounced, mold, rankings, densities, rigel, tm, phrased,
# Nearest to governor: ended, dwindled, vanities, mara, coalitions, encyclopedia, tristan, received,
# Nearest to proposed: bijections, qurra, companies, kundalini, clause, unobstructed, lansing, sw,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4056 0.0410 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4261 0.0396 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4345 0.0397 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3943 0.0396 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3892 0.0398 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4461 0.0396 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3877 0.0398 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3722 0.0396 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3909 0.0396 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3617 0.0396 sec/batch
# Nearest to also: agreements, caution, of, vdots, paragraph, it, alla, wholly,
# Nearest to state: kmaq, nurseries, evictions, pervasive, vers, arnstadt, hologram, citizen,
# Nearest to s: gerald, aradia, company, bhaktivedanta, glycoprotein, importer, lenin, ninti,
# Nearest to have: polygamist, hellenistic, nullified, hydrography, carnac, opponents, kierkegaard, scavenge,
# Nearest to had: bluebeard, arquette, still, minting, istria, garnered, cdm, organizers,
# Nearest to if: decide, algebraically, overwork, arraignment, arguments, jacobian, epilepsy, indistinguishable,
# Nearest to his: he, mother, him, graduated, dynasty, disruption, wendy, respectfully,
# Nearest to between: obliquely, south, camulodunum, squadrons, civilized, aorta, minestrone, voortrekker,
# Nearest to nobel: screenwriter, linz, activist, comedienne, one, gracchi, laureate, writer,
# Nearest to account: trillion, insulating, regents, malagasy, felt, clerics, takeda, though,
# Nearest to notes: poses, melchior, orthogonal, legitimize, bighorn, xyz, pertains, ibis,
# Nearest to hit: flavors, midseason, tom, melvin, pal, inexpensive, lifeson, quarried,
# Nearest to ocean: region, degrades, odp, oceans, ft, slopes, banu, sea,
# Nearest to additional: bounced, compressed, mold, densities, tm, phrased, rigel, rankings,
# Nearest to governor: ended, vanities, dwindled, mara, presides, coalitions, maryland, president,
# Nearest to proposed: bijections, qurra, companies, kundalini, clause, pronoun, lansing, unobstructed,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3602 0.0411 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3909 0.0398 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3312 0.0396 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3656 0.0396 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3796 0.0398 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3729 0.0398 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4035 0.0395 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3586 0.0397 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3414 0.0397 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3178 0.0396 sec/batch
# Nearest to also: agreements, of, caution, vdots, it, shredded, paragraph, tilapia,
# Nearest to state: nurseries, kmaq, evictions, pervasive, executive, vers, arnstadt, citizen,
# Nearest to s: aradia, company, gerald, ninti, glycoprotein, mayer, bhaktivedanta, loretta,
# Nearest to have: polygamist, hellenistic, opponents, kierkegaard, freezer, hydrography, individual, carnac,
# Nearest to had: still, minting, bluebeard, finesse, arquette, organizers, fell, suffering,
# Nearest to if: decide, algebraically, overwork, arraignment, indistinguishable, jacobian, abjads, materia,
# Nearest to his: he, him, mother, disruption, sons, vengeance, graduated, says,
# Nearest to between: south, obliquely, camulodunum, leukemia, civilized, voortrekker, minestrone, squadrons,
# Nearest to nobel: linz, comedienne, gracchi, buke, activist, screenwriter, hunsr, trader,
# Nearest to account: trillion, malagasy, insulating, regents, clerics, cra, takeda, nazionale,
# Nearest to notes: poses, melchior, orthogonal, electronic, pepsico, xyz, pertains, ibis,
# Nearest to hit: midseason, tom, flavors, melvin, pal, lifeson, sailor, torturing,
# Nearest to ocean: region, degrades, ft, oceans, slopes, odp, caribbean, vessels,
# Nearest to additional: bounced, compressed, densities, mold, synaptic, rankings, animation, payloads,
# Nearest to governor: ended, vanities, coalitions, mara, presides, dwindled, maryland, announce,
# Nearest to proposed: bijections, qurra, kundalini, clause, companies, pronoun, howdy, analyte,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3355 0.0410 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3294 0.0397 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3718 0.0396 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3471 0.0396 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3912 0.0396 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3033 0.0397 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2936 0.0397 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3360 0.0397 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1990 0.0399 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2887 0.0397 sec/batch
# Nearest to also: agreements, of, vdots, it, caution, alla, harel, shredded,
# Nearest to state: nurseries, evictions, arnstadt, kmaq, pervasive, executive, atlantic, reconstruction,
# Nearest to s: aradia, mayer, ninti, lenin, gerald, company, vlaams, moltke,
# Nearest to have: polygamist, kierkegaard, hydrography, carnac, freezer, hellenistic, stillness, skeleton,
# Nearest to had: minting, still, bluebeard, urals, arquette, fell, organizers, gerardus,
# Nearest to if: decide, algebraically, overwork, indistinguishable, exp, arraignment, follows, abjads,
# Nearest to his: he, him, mother, vengeance, disruption, wayland, mok, seedlings,
# Nearest to between: south, obliquely, camulodunum, voortrekker, minestrone, civilized, squadrons, golfing,
# Nearest to nobel: linz, one, biologist, comedienne, activist, nicolas, cartoonist, gracchi,
# Nearest to account: trillion, malagasy, insulating, regents, takeda, clerics, cra, nazionale,
# Nearest to notes: poses, melchior, orthogonal, pietro, legitimize, pepsico, pertains, electronic,
# Nearest to hit: midseason, tom, flavors, she, melvin, torturing, lifeson, pal,
# Nearest to ocean: region, slopes, oceans, degrades, odp, ft, caribbean, soils,
# Nearest to additional: bounced, compressed, mold, densities, rankings, synaptic, payloads, tm,
# Nearest to governor: vanities, presides, ended, mara, coalitions, dwindled, rhoda, maryland,
# Nearest to proposed: qurra, bijections, kundalini, clause, companies, armaments, analyte, lansing,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3221 0.0410 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2954 0.0397 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3603 0.0185 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2263 0.0395 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2003 0.0397 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.1834 0.0397 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2020 0.0397 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1912 0.0397 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2157 0.0396 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1645 0.0396 sec/batch
# Nearest to also: agreements, it, vdots, of, caution, tilapia, alla, shredded,
# Nearest to state: evictions, nurseries, kmaq, arnstadt, citizen, reconstruction, executive, pervasive,
# Nearest to s: aradia, gerald, company, mayer, loretta, tincture, lenin, ninti,
# Nearest to have: polygamist, hellenistic, kierkegaard, freezer, stillness, opponents, hydrography, carnac,
# Nearest to had: still, bluebeard, minting, cdm, fell, surrender, finesse, istria,
# Nearest to if: algebraically, decide, overwork, indistinguishable, materia, arraignment, abjads, exp,
# Nearest to his: he, him, mother, vengeance, seedlings, mok, says, understated,
# Nearest to between: south, obliquely, camulodunum, voortrekker, minestrone, timur, border, patinkin,
# Nearest to nobel: linz, comedienne, biologist, activist, cartoonist, one, buke, nicolas,
# Nearest to account: trillion, malagasy, insulating, regents, takeda, cra, clerics, mlk,
# Nearest to notes: poses, melchior, pietro, structured, pepsico, pertains, wikiquote, ibis,
# Nearest to hit: midseason, tom, flavors, she, melvin, hitting, torturing, airman,
# Nearest to ocean: oceans, region, degrades, soils, slopes, migrate, odp, ft,
# Nearest to additional: compressed, bounced, densities, mold, tm, payloads, animation, rigel,
# Nearest to governor: presides, vanities, mara, ended, coalitions, rhoda, dwindled, announce,
# Nearest to proposed: bijections, qurra, armaments, kundalini, clause, companies, analyte, lansing,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2525 0.0411 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2234 0.0396 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2044 0.0395 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1085 0.0397 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.2012 0.0396 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1622 0.0396 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1124 0.0398 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1688 0.0397 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1734 0.0397 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1514 0.0398 sec/batch
# Nearest to also: agreements, it, of, vdots, tilapia, caution, shredded, visio,
# Nearest to state: kmaq, evictions, nurseries, arnstadt, citizen, pervasive, atlantic, executive,
# Nearest to s: aradia, mayer, ninti, tincture, loretta, accentuation, lenin, vlaams,
# Nearest to have: polygamist, hellenistic, antiwar, hydrography, freezer, carnac, individual, opponents,
# Nearest to had: minting, still, fell, finally, arquette, bluebeard, finesse, organizers,
# Nearest to if: algebraically, decide, magma, overwork, abjads, materia, exp, jacobian,
# Nearest to his: he, him, mother, vengeance, seedlings, mok, understated, betrayal,
# Nearest to between: south, obliquely, civilized, timur, camulodunum, voortrekker, patinkin, areas,
# Nearest to nobel: linz, comedienne, biologist, danson, buke, gracchi, activist, laureate,
# Nearest to account: trillion, malagasy, insulating, takeda, regents, clerics, cra, mlk,
# Nearest to notes: poses, melchior, pietro, pertains, electronic, octaves, cantus, ibis,
# Nearest to hit: midseason, she, hitting, melvin, tom, thieves, flavors, torturing,
# Nearest to ocean: oceans, region, degrades, migrate, soils, caribbean, slopes, odp,
# Nearest to additional: compressed, bounced, densities, payloads, coulombs, mold, rankings, tm,
# Nearest to governor: presides, mara, vanities, coalitions, rhoda, president, dwindled, amendment,
# Nearest to proposed: bijections, qurra, kundalini, analyte, armaments, clause, observing, companies,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1673 0.0412 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2088 0.0400 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1602 0.0397 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1299 0.0395 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1865 0.0398 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1513 0.0396 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1921 0.0397 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1146 0.0396 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1032 0.0397 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1749 0.0398 sec/batch
# Nearest to also: agreements, of, it, vdots, shredded, caution, visio, tilapia,
# Nearest to state: kmaq, evictions, nurseries, citizen, equiv, pervasive, arnstadt, reconstruction,
# Nearest to s: aradia, ninti, mayer, loretta, tincture, goddamn, moltke, importer,
# Nearest to have: polygamist, hellenistic, multicoloured, freezer, individual, carnac, antiwar, kierkegaard,
# Nearest to had: arquette, still, finally, organizers, minting, fell, moved, interfered,
# Nearest to if: decide, algebraically, jacobian, arraignment, magma, abjads, overwork, exp,
# Nearest to his: he, him, mother, vengeance, mok, understated, maximin, says,
# Nearest to between: south, obliquely, voortrekker, milner, camulodunum, timur, areas, civilized,
# Nearest to nobel: linz, danson, biologist, comedienne, buke, activist, gracchi, prize,
# Nearest to account: trillion, malagasy, insulating, takeda, cra, mlk, bandgap, nazionale,
# Nearest to notes: poses, melchior, pietro, electronic, rhythms, structured, octaves, predication,
# Nearest to hit: midseason, she, thieves, flavors, hitting, torturing, fewest, tom,
# Nearest to ocean: region, oceans, degrades, migrate, soils, slopes, caribbean, fissure,
# Nearest to additional: bounced, compressed, densities, coulombs, payloads, sawmills, mold, rankings,
# Nearest to governor: presides, vanities, mara, coalitions, rhoda, president, announce, tampere,
# Nearest to proposed: bijections, qurra, kundalini, observing, analyte, armaments, schmitt, clause,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1934 0.0411 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1507 0.0397 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1516 0.0398 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1676 0.0395 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1528 0.0397 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1250 0.0397 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1395 0.0399 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1153 0.0397 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2073 0.0397 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2044 0.0397 sec/batch
# Nearest to also: agreements, of, it, vdots, prevalent, khruschev, shredded, visio,
# Nearest to state: evictions, kmaq, nurseries, arnstadt, citizen, secretaries, yale, reconstruction,
# Nearest to s: aradia, loretta, lenin, mayer, ninti, goddamn, gerald, purge,
# Nearest to have: polygamist, freezer, multicoloured, kierkegaard, hellenistic, cong, antiwar, carnac,
# Nearest to had: still, minting, interfered, arquette, finally, fell, bluebeard, constance,
# Nearest to if: decide, algebraically, jacobian, abjads, arraignment, overwork, indistinguishable, comparison,
# Nearest to his: he, him, mother, vengeance, mok, graduated, nephew, was,
# Nearest to between: south, obliquely, timur, voortrekker, camulodunum, areas, milner, civilized,
# Nearest to nobel: linz, biologist, comedienne, activist, danson, buke, prize, one,
# Nearest to account: trillion, malagasy, ethnography, takeda, cra, mlk, bazoft, pulsating,
# Nearest to notes: octaves, electronic, melchior, poses, pietro, structured, rhythms, cantus,
# Nearest to hit: midseason, thieves, she, hitting, torturing, airman, tom, flavors,
# Nearest to ocean: oceans, region, degrades, migrate, caribbean, soils, slopes, fissure,
# Nearest to additional: bounced, compressed, rankings, payloads, samogitia, sawmills, eccl, densities,
# Nearest to governor: presides, vanities, mara, coalitions, rhoda, announce, received, tampere,
# Nearest to proposed: bijections, qurra, observing, kundalini, clause, analyte, armaments, inuvialuit,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2376 0.0411 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1149 0.0396 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1266 0.0396 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1223 0.0398 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9996 0.0397 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1221 0.0398 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1228 0.0397 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1046 0.0398 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1660 0.0077 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1079 0.0396 sec/batch
# Nearest to also: agreements, of, it, vdots, shredded, prevalent, khruschev, internet,
# Nearest to state: evictions, kmaq, nurseries, arnstadt, atlantic, yale, coordinates, reconstruction,
# Nearest to s: aradia, mayer, loretta, ninti, goddamn, weekdays, hours, tincture,
# Nearest to have: polygamist, multicoloured, hydrography, antiwar, freezer, stillness, hunter, cong,
# Nearest to had: interfered, minting, moved, still, arquette, finally, conceded, urals,
# Nearest to if: decide, algebraically, arraignment, magma, abjads, integrable, jacobian, whichever,
# Nearest to his: he, him, mother, vengeance, mok, understated, graduated, apo,
# Nearest to between: south, obliquely, voortrekker, areas, timur, southern, milner, border,
# Nearest to nobel: biologist, comedienne, linz, prize, danson, buke, activist, gracchi,
# Nearest to account: trillion, malagasy, cra, takeda, mlk, insulating, ethnography, pulsating,
# Nearest to notes: octaves, rhythms, structured, electronic, poses, melchior, cantus, wikiquote,
# Nearest to hit: midseason, thieves, hitting, she, airman, torturing, flavors, babe,
# Nearest to ocean: oceans, degrades, region, migrate, slopes, soils, caribbean, fissure,
# Nearest to additional: compressed, bounced, payloads, densities, rankings, coulombs, complication, samogitia,
# Nearest to governor: presides, vanities, mara, announce, salina, maryland, rhoda, tampere,
# Nearest to proposed: qurra, bijections, observing, clause, kundalini, analyte, inuvialuit, constructivists,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0515 0.0410 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0667 0.0397 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0846 0.0396 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0455 0.0395 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0978 0.0397 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0109 0.0397 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0650 0.0397 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0562 0.0398 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1127 0.0397 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9912 0.0396 sec/batch
# Nearest to also: agreements, of, it, shredded, vdots, filmed, visio, metallurgical,
# Nearest to state: kmaq, evictions, nurseries, arnstadt, atlantic, hologram, yale, equiv,
# Nearest to s: aradia, ninti, goddamn, government, weekdays, bargaining, loretta, country,
# Nearest to have: polygamist, hunter, freezer, multicoloured, are, has, hydrography, infective,
# Nearest to had: still, minting, finally, interfered, moved, spartans, conceded, arquette,
# Nearest to if: decide, algebraically, magma, arraignment, overwork, indistinguishable, whichever, declare,
# Nearest to his: he, him, vengeance, mother, mok, understated, was, apo,
# Nearest to between: south, obliquely, southern, timur, areas, voortrekker, border, milner,
# Nearest to nobel: comedienne, biologist, prize, linz, activist, danson, laureate, buke,
# Nearest to account: trillion, malagasy, cra, takeda, insulating, bandgap, bazoft, mlk,
# Nearest to notes: octaves, rhythms, structured, cantus, melchior, pietro, wikiquote, poses,
# Nearest to hit: midseason, hitting, thieves, babe, airman, she, fewest, sailor,
# Nearest to ocean: oceans, degrades, region, migrate, caribbean, slopes, fissure, soils,
# Nearest to additional: compressed, bounced, coulombs, tm, rankings, densities, complication, samogitia,
# Nearest to governor: presides, mara, vanities, announce, rhoda, salina, current, maryland,
# Nearest to proposed: bijections, qurra, observing, analyte, kundalini, schmitt, clause, detector,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9997 0.0412 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0102 0.0397 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9776 0.0397 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0450 0.0397 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0264 0.0397 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0194 0.0395 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0617 0.0398 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0995 0.0398 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0408 0.0397 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0012 0.0397 sec/batch
# Nearest to also: of, agreements, it, shredded, vdots, visio, filmed, tilapia,
# Nearest to state: kmaq, evictions, equiv, nurseries, yale, atlantic, arnstadt, observable,
# Nearest to s: aradia, goddamn, ninti, tincture, weekdays, loretta, mayer, ie,
# Nearest to have: polygamist, has, multicoloured, hunter, freezer, are, stillness, aloft,
# Nearest to had: finally, interfered, still, minting, moved, conceded, jef, he,
# Nearest to if: decide, algebraically, arraignment, magma, integrable, declare, is, circ,
# Nearest to his: he, him, mother, understated, mok, vengeance, apo, graduated,
# Nearest to between: south, obliquely, southern, areas, timur, milner, voortrekker, civilized,
# Nearest to nobel: danson, comedienne, linz, biologist, buke, activist, prize, laureate,
# Nearest to account: trillion, malagasy, takeda, cra, bandgap, insulating, mlk, ethnography,
# Nearest to notes: octaves, cantus, rhythms, pietro, melchior, electronic, structured, poses,
# Nearest to hit: midseason, hitting, thieves, fewest, babe, transporter, airman, sailor,
# Nearest to ocean: oceans, degrades, region, migrate, caribbean, slopes, fissure, soils,
# Nearest to additional: compressed, coulombs, complication, bounced, densities, tm, payloads, undress,
# Nearest to governor: presides, mara, vanities, salina, announce, rhoda, maryland, received,
# Nearest to proposed: bijections, analyte, observing, qurra, detector, hemicellulose, inuvialuit, schmitt,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0269 0.0411 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0452 0.0398 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0935 0.0397 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0398 0.0397 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0415 0.0396 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0615 0.0398 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0576 0.0397 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0412 0.0395 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0790 0.0397 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0631 0.0397 sec/batch
# Nearest to also: of, agreements, it, shredded, qatar, filmed, vdots, metallurgical,
# Nearest to state: evictions, kmaq, nurseries, equiv, atlantic, yale, arnstadt, governor,
# Nearest to s: aradia, goddamn, weekdays, ninti, loretta, ninth, moltke, ie,
# Nearest to have: polygamist, has, freezer, hunter, cong, bayqongyr, multicoloured, are,
# Nearest to had: interfered, finally, still, minting, moved, spartans, philosophic, barons,
# Nearest to if: decide, algebraically, declare, arraignment, integrable, indistinguishable, circ, magma,
# Nearest to his: he, him, was, mother, graduated, understated, vengeance, mok,
# Nearest to between: south, obliquely, southern, camulodunum, milner, timur, voortrekker, civilized,
# Nearest to nobel: danson, activist, biologist, buke, prize, linz, comedienne, nagano,
# Nearest to account: trillion, malagasy, cra, mlk, takeda, ethnography, bandgap, steve,
# Nearest to notes: octaves, cantus, pietro, structured, melchior, rhythms, wikiquote, poses,
# Nearest to hit: midseason, thieves, hitting, babe, airman, fewest, bales, sailor,
# Nearest to ocean: oceans, degrades, atlantic, migrate, caribbean, region, tropospheric, fissure,
# Nearest to additional: compressed, bounced, coulombs, complication, densities, samogitia, payloads, undress,
# Nearest to governor: presides, mara, vanities, announce, salina, rhoda, received, state,
# Nearest to proposed: observing, bijections, analyte, qurra, detector, schmitt, clause, kundalini,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0388 0.0411 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9946 0.0397 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9994 0.0396 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0688 0.0396 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0656 0.0396 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1245 0.0396 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1055 0.0397 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0176 0.0391 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9897 0.0395 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0023 0.0394 sec/batch
# Nearest to also: of, agreements, it, shredded, qatar, filmed, khruschev, gus,
# Nearest to state: evictions, kmaq, governor, secretaries, arnstadt, nurseries, mississippi, yale,
# Nearest to s: aradia, goddamn, ninti, weekdays, loretta, mayer, hours, lexcorp,
# Nearest to have: polygamist, has, are, freezer, marginalised, cong, stillness, aloft,
# Nearest to had: interfered, minting, still, moved, finally, constance, he, urals,
# Nearest to if: decide, algebraically, integrable, arraignment, declare, can, indistinguishable, circ,
# Nearest to his: he, him, was, mok, graduated, understated, apo, mother,
# Nearest to between: south, obliquely, southern, timur, milner, camulodunum, voortrekker, border,
# Nearest to nobel: prize, biologist, activist, comedienne, linz, danson, laureate, buke,
# Nearest to account: trillion, malagasy, mlk, cra, takeda, shelves, ethnography, michener,
# Nearest to notes: octaves, rhythms, structured, pietro, cantus, wikiquote, poses, octave,
# Nearest to hit: midseason, thieves, hitting, babe, airman, fewest, florentines, hakim,
# Nearest to ocean: oceans, degrades, atlantic, migrate, region, caribbean, fissure, tropospheric,
# Nearest to additional: compressed, bounced, eccl, samogitia, coulombs, complication, densities, newsmagazine,
# Nearest to governor: presides, mara, vanities, salina, state, announce, rhoda, maryland,
# Nearest to proposed: observing, bijections, analyte, detector, qurra, lansing, hemicellulose, junkers,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9506 0.0410 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9914 0.0394 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0132 0.0395 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9960 0.0514 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0662 0.0397 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0330 0.0365 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0180 0.0395 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9789 0.0394 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0098 0.0395 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9458 0.0395 sec/batch
# Nearest to also: of, agreements, it, shredded, qatar, disputed, filmed, gus,
# Nearest to state: kmaq, evictions, knoxville, atlantic, mississippi, governor, arnstadt, yale,
# Nearest to s: aradia, goddamn, ninti, weekdays, loretta, mayer, hours, lexcorp,
# Nearest to have: polygamist, has, are, freezer, hunter, marginalised, aloft, hydrography,
# Nearest to had: still, interfered, he, moved, finally, minting, constance, spartans,
# Nearest to if: decide, algebraically, arraignment, declare, vx, magma, integrable, true,
# Nearest to his: he, him, was, graduated, mother, understated, mok, nephew,
# Nearest to between: south, obliquely, timur, southern, camulodunum, milner, border, voortrekker,
# Nearest to nobel: prize, activist, biologist, laureate, comedienne, danson, linz, buke,
# Nearest to account: trillion, malagasy, mlk, michener, cra, takeda, shelves, steve,
# Nearest to notes: octaves, cantus, rhythms, octave, pietro, structured, wikiquote, melchior,
# Nearest to hit: midseason, thieves, hitting, airman, babe, fewest, hakim, sailor,
# Nearest to ocean: oceans, atlantic, degrades, caribbean, islands, tropospheric, windsurfing, region,
# Nearest to additional: compressed, bounced, coulombs, samogitia, payloads, eccl, tm, transonic,
# Nearest to governor: presides, mara, vanities, announce, state, salina, rhoda, naas,
# Nearest to proposed: observing, bijections, analyte, detector, qurra, junkers, hemicellulose, schmitt,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9694 0.0411 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9161 0.0396 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0024 0.0396 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9972 0.0394 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9880 0.0396 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9808 0.0397 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8993 0.0395 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9296 0.0397 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8903 0.0395 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9294 0.0398 sec/batch
# Nearest to also: of, agreements, it, shredded, metallurgical, filmed, qatar, tarnishes,
# Nearest to state: kmaq, evictions, atlantic, knoxville, yale, mississippi, governor, nurseries,
# Nearest to s: goddamn, weekdays, ninti, aradia, whose, bargaining, cricketing, ninth,
# Nearest to have: has, are, polygamist, hunter, marginalised, freezer, individual, hydrography,
# Nearest to had: still, finally, he, interfered, spartans, minting, moved, constance,
# Nearest to if: decide, algebraically, arraignment, declare, vx, magma, integrable, be,
# Nearest to his: he, him, was, graduated, understated, mok, mother, filius,
# Nearest to between: south, obliquely, southern, timur, areas, milner, camulodunum, border,
# Nearest to nobel: prize, activist, biologist, comedienne, danson, buke, laureate, linz,
# Nearest to account: trillion, malagasy, cra, michener, mlk, shelves, takeda, rebounded,
# Nearest to notes: octaves, pietro, cantus, rhythms, melchior, octave, wikiquote, structured,
# Nearest to hit: midseason, hitting, thieves, babe, airman, fewest, sailor, nu,
# Nearest to ocean: oceans, atlantic, caribbean, degrades, windsurfing, region, tropospheric, islands,
# Nearest to additional: compressed, bounced, samogitia, coulombs, payloads, eccl, undress, tm,
# Nearest to governor: presides, mara, vanities, salina, state, announce, rhoda, current,
# Nearest to proposed: observing, bijections, analyte, detector, hemicellulose, junkers, heisenberg, qurra,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9715 0.0407 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9547 0.0398 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9348 0.0395 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0034 0.0395 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0330 0.0395 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9199 0.0396 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9685 0.0413 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9421 0.0432 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9745 0.0396 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9624 0.0397 sec/batch
# Nearest to also: of, it, agreements, shredded, filmed, qatar, metallurgical, visio,
# Nearest to state: kmaq, evictions, atlantic, observable, nurseries, knoxville, yale, equiv,
# Nearest to s: goddamn, aradia, ninti, weekdays, whose, lexcorp, bargaining, distributed,
# Nearest to have: has, are, freezer, polygamist, individual, marginalised, stillness, hunter,
# Nearest to had: still, interfered, he, finally, moved, minting, constance, philosophic,
# Nearest to if: algebraically, decide, declare, arraignment, integrable, true, circ, whichever,
# Nearest to his: he, him, was, graduated, understated, apo, mok, mother,
# Nearest to between: south, obliquely, southern, timur, milner, patinkin, areas, camulodunum,
# Nearest to nobel: prize, activist, laureate, comedienne, nagano, biologist, danson, linz,
# Nearest to account: trillion, malagasy, cra, mlk, michener, shelves, ethnography, rebounded,
# Nearest to notes: octaves, pietro, melchior, cantus, rhythms, wikiquote, octave, structured,
# Nearest to hit: midseason, thieves, hitting, nu, babe, airman, sailor, fewest,
# Nearest to ocean: oceans, atlantic, caribbean, degrades, tropospheric, windsurfing, warm, fissure,
# Nearest to additional: compressed, bounced, coulombs, complication, eccl, payloads, tm, densities,
# Nearest to governor: presides, vanities, mara, announce, rhoda, salina, naas, maryland,
# Nearest to proposed: observing, analyte, bijections, detector, hemicellulose, junkers, sive, heisenberg,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9657 0.0414 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9261 0.0394 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9748 0.0396 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9550 0.0397 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0203 0.0396 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9828 0.0399 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9694 0.0396 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9266 0.0397 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9358 0.0395 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0083 0.0398 sec/batch
# Nearest to also: of, it, agreements, filmed, qatar, is, disputed, shredded,
# Nearest to state: evictions, kmaq, nurseries, atlantic, knoxville, observable, governor, yale,
# Nearest to s: goddamn, whose, aradia, ninti, lexcorp, ninth, weekdays, bargaining,
# Nearest to have: has, are, freezer, been, polygamist, marginalised, adoptionism, stillness,
# Nearest to had: still, interfered, finally, minting, moved, he, philosophic, constance,
# Nearest to if: decide, algebraically, declare, arraignment, integrable, whichever, or, comparison,
# Nearest to his: he, him, graduated, apo, mok, was, understated, colonist,
# Nearest to between: southern, south, obliquely, timur, areas, milner, border, abscissa,
# Nearest to nobel: prize, activist, laureate, biologist, buke, nagano, linz, comedienne,
# Nearest to account: trillion, malagasy, cra, mlk, rebounded, ethnography, michener, shelves,
# Nearest to notes: octaves, cantus, octave, rhythms, pietro, wikiquote, poses, structured,
# Nearest to hit: midseason, thieves, hitting, nu, airman, babe, bales, fewest,
# Nearest to ocean: oceans, atlantic, caribbean, degrades, tropospheric, windsurfing, warm, trunk,
# Nearest to additional: compressed, bounced, samogitia, coulombs, eccl, complication, provided, payloads,
# Nearest to governor: presides, vanities, mara, announce, salina, judiciary, rhoda, naas,
# Nearest to proposed: observing, analyte, bijections, hemicellulose, detector, junkers, qurra, proposal,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9314 0.0413 sec/batch
# ...
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8094 0.0393 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8075 0.0398 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7932 0.0395 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8349 0.0395 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8709 0.0398 sec/batch
# Nearest to also: of, and, it, in, is, the, with, for,
# Nearest to state: knoxville, mcgowan, governor, atlantic, kmaq, bubi, evictions, mississippi,
# Nearest to s: the, nine, in, four, two, was, and, eight,
# Nearest to have: are, been, has, for, as, some, that, most,
# Nearest to had: still, was, were, that, he, went, fell, few,
# Nearest to if: or, declare, anywhere, vx, algebraically, arraignment, proceed, banach,
# Nearest to his: he, him, career, graduated, was, mok, spent, gym,
# Nearest to between: with, southern, of, the, separated, nand, through, controlled,
# Nearest to nobel: prize, nagano, pond, laureate, activist, astrophysicist, buke, basf,
# Nearest to account: trillion, malagasy, cra, shelves, michener, dreadnoughts, rebounded, mlk,
# Nearest to notes: octaves, octave, cantus, wikiquote, felling, trending, pietro, channelling,
# Nearest to hit: hits, midseason, nu, hitting, airman, hb, defensively, hakim,
# Nearest to ocean: atlantic, oceans, broadcast, shortwave, intelsat, expedition, deepest, inmarsat,
# Nearest to additional: provided, tte, eccl, added, eukaryotes, mold, unjustified, voices,
# Nearest to governor: state, presides, rhoda, controlled, laeken, bustamante, duvalier, secretary,
# Nearest to proposed: proposal, prior, analyte, enceladus, nomenclature, schmitt, entice, merozoites,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8038 0.0414 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8111 0.0393 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8010 0.0398 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8214 0.0398 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8175 0.0398 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8299 0.0396 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8125 0.0399 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8117 0.0393 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8402 0.0398 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8483 0.0394 sec/batch
# Nearest to also: of, and, is, it, in, a, the, with,
# Nearest to state: governor, bubi, knoxville, observable, mcgowan, states, evictions, atlantic,
# Nearest to s: the, nine, in, two, four, eight, that, and,
# Nearest to have: are, been, has, as, some, for, that, most,
# Nearest to had: was, still, were, he, that, went, few, fell,
# Nearest to if: declare, algebraically, or, arraignment, anywhere, vx, banach, comparison,
# Nearest to his: he, him, career, was, graduated, wrote, spent, mok,
# Nearest to between: with, southern, of, the, and, separated, autocephaly, dominant,
# Nearest to nobel: prize, nagano, pond, buke, activist, astrophysicist, laureate, basf,
# Nearest to account: trillion, cra, malagasy, shelves, dreadnoughts, mlk, rebounded, michener,
# Nearest to notes: octaves, octave, cantus, wikiquote, felling, trending, parable, collected,
# Nearest to hit: hits, midseason, hitting, hb, nu, airman, hakim, defensively,
# Nearest to ocean: atlantic, warm, broadcast, tropospheric, oceans, intelsat, shortwave, expedition,
# Nearest to additional: provided, tte, announced, added, eccl, eukaryotes, voices, showed,
# Nearest to governor: state, presides, controlled, laeken, rhoda, execute, duvalier, secretary,
# Nearest to proposed: proposal, prior, nomenclature, analyte, naming, enceladus, archeology, schmitt,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8099 0.0410 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8083 0.0392 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8026 0.0394 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7798 0.0397 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8864 0.0396 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8351 0.0397 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9658 0.0392 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8639 0.0396 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9017 0.0400 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8059 0.0398 sec/batch
# Nearest to also: of, it, and, a, is, with, in, for,
# Nearest to state: governor, knoxville, states, bubi, observable, mcgowan, mississippi, akihito,
# Nearest to s: the, in, nine, and, two, four, was, that,
# Nearest to have: are, has, been, for, as, some, that, most,
# Nearest to had: was, he, still, were, that, went, fell, never,
# Nearest to if: or, declare, arraignment, anywhere, vx, algebraically, leq, banach,
# Nearest to his: he, him, was, career, graduated, spent, soon, worked,
# Nearest to between: with, of, southern, the, and, controlled, separated, nand,
# Nearest to nobel: prize, nagano, pond, astrophysicist, laureate, activist, buke, franke,
# Nearest to account: trillion, malagasy, shelves, cra, mlk, rebounded, dreadnoughts, michener,
# Nearest to notes: octaves, octave, cantus, wikiquote, felling, trending, citations, nations,
# Nearest to hit: hits, midseason, airman, hitting, nu, hb, hakim, thieves,
# Nearest to ocean: atlantic, broadcast, intelsat, warm, tropospheric, shortwave, inmarsat, oceans,
# Nearest to additional: provided, announced, tte, eccl, showed, added, voices, densities,
# Nearest to governor: state, controlled, laeken, execute, presides, rhoda, hydrosphere, fletcher,
# Nearest to proposed: proposal, prior, nomenclature, naming, enceladus, analyte, schmitt, observing,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7407 0.0412 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8181 0.0394 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7453 0.0397 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8142 0.0399 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7854 0.0397 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8270 0.0397 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8424 0.0229 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7965 0.0398 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7845 0.0393 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8286 0.0396 sec/batch
# Nearest to also: of, and, is, it, with, include, which, in,
# Nearest to state: knoxville, bubi, governor, observable, states, mississippi, mcgowan, akihito,
# Nearest to s: the, in, and, nine, whose, two, that, four,
# Nearest to have: are, has, been, some, as, for, most, that,
# Nearest to had: was, were, he, still, went, fell, that, never,
# Nearest to if: arraignment, declare, vx, algebraically, proceed, anywhere, leq, or,
# Nearest to his: he, him, was, graduated, career, then, died, spent,
# Nearest to between: with, of, the, southern, and, nand, controlled, separated,
# Nearest to nobel: prize, laureate, nagano, pond, astrophysicist, activist, buke, basf,
# Nearest to account: malagasy, trillion, cra, michener, shelves, mlk, dreadnoughts, inadvertantly,
# Nearest to notes: octaves, octave, cantus, wikiquote, felling, surfer, trending, citations,
# Nearest to hit: hits, midseason, airman, hitting, nu, hb, hakim, bales,
# Nearest to ocean: warm, atlantic, oceans, broadcast, expedition, tropospheric, intelsat, warmer,
# Nearest to additional: provided, announced, tte, eccl, added, showed, eukaryotes, densities,
# Nearest to governor: state, controlled, rhoda, laeken, fletcher, execute, presides, hydrosphere,
# Nearest to proposed: proposal, prior, nomenclature, naming, enceladus, analyte, schmitt, entice,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8052 0.0410 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7816 0.0399 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7845 0.0391 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7491 0.0390 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8238 0.0396 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8013 0.0397 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8520 0.0396 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7404 0.0396 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7751 0.0398 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7348 0.0397 sec/batch
# Nearest to also: of, is, and, it, with, in, the, include,
# Nearest to state: knoxville, governor, mcgowan, bubi, observable, created, akihito, mississippi,
# Nearest to s: the, in, that, and, two, whose, nine, four,
# Nearest to have: are, been, has, some, as, most, that, for,
# Nearest to had: was, still, were, fell, he, went, that, never,
# Nearest to if: leq, declare, or, arraignment, algebraically, anywhere, vx, banach,
# Nearest to his: he, him, was, career, graduated, mok, gym, spent,
# Nearest to between: with, of, the, southern, and, through, controlled, nand,
# Nearest to nobel: prize, nagano, pond, laureate, activist, astrophysicist, buke, basf,
# Nearest to account: malagasy, trillion, shelves, michener, cra, dreadnoughts, evidence, rebounded,
# Nearest to notes: octaves, octave, cantus, wikiquote, felling, surfer, eis, nations,
# Nearest to hit: hits, hitting, hb, airman, nu, midseason, batted, inelastic,
# Nearest to ocean: atlantic, warm, oceans, tropospheric, expedition, intelsat, upwelling, inmarsat,
# Nearest to additional: provided, tte, announced, added, voices, eccl, showed, plasmid,
# Nearest to governor: state, controlled, laeken, presides, rhoda, peripheral, fletcher, hydrosphere,
# Nearest to proposed: prior, proposal, enceladus, naming, nomenclature, analyte, schmitt, archeology,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7166 0.0408 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8121 0.0394 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8149 0.0395 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7786 0.0395 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7702 0.0395 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8621 0.0396 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8188 0.0395 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7445 0.0397 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7715 0.0394 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7836 0.0401 sec/batch
# Nearest to also: of, and, is, in, it, include, for, with,
# Nearest to state: mcgowan, observable, bubi, governor, knoxville, states, mississippi, created,
# Nearest to s: the, in, two, and, four, nine, a, that,
# Nearest to have: are, been, has, some, as, that, most, for,
# Nearest to had: was, still, were, fell, he, went, that, never,
# Nearest to if: declare, or, there, leq, anywhere, arraignment, banach, algebraically,
# Nearest to his: he, him, was, career, graduated, mok, died, gym,
# Nearest to between: with, of, the, southern, dominant, nand, through, and,
# Nearest to nobel: prize, nagano, laureate, pond, astrophysicist, activist, buke, basf,
# Nearest to account: malagasy, shelves, cra, trillion, dreadnoughts, michener, rebounded, evidence,
# Nearest to notes: octaves, octave, cantus, felling, wikiquote, citations, exchange, weisstein,
# Nearest to hit: hits, hitting, airman, nu, hb, midseason, hakim, hellespont,
# Nearest to ocean: warm, oceans, atlantic, warmer, expedition, upwelling, tropospheric, intelsat,
# Nearest to additional: provided, announced, tte, added, eccl, voices, showed, eukaryotes,
# Nearest to governor: state, controlled, laeken, rhoda, fletcher, presides, peripheral, execute,
# Nearest to proposed: proposal, prior, enceladus, nomenclature, naming, analyte, entice, schmitt,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8434 0.0413 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8122 0.0394 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7850 0.0395 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8048 0.0394 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8475 0.0394 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8194 0.0395 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7899 0.0399 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8094 0.0400 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7680 0.0395 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7704 0.0399 sec/batch
# Nearest to also: of, and, is, in, with, a, it, for,
# Nearest to state: bubi, states, governor, mcgowan, knoxville, observable, mississippi, kmaq,
# Nearest to s: the, two, in, four, and, nine, eight, six,
# Nearest to have: are, been, has, some, as, for, that, most,
# Nearest to had: was, still, were, that, went, fell, he, the,
# Nearest to if: declare, arraignment, or, banach, vx, leq, comparison, algebraically,
# Nearest to his: he, him, career, graduated, was, irrigation, mok, died,
# Nearest to between: with, of, the, and, southern, dominant, through, a,
# Nearest to nobel: prize, nagano, pond, laureate, buke, astrophysicist, activist, basf,
# Nearest to account: malagasy, cra, trillion, shelves, dreadnoughts, michener, rebounded, capricious,
# Nearest to notes: octave, octaves, cantus, felling, wikiquote, exchange, weisstein, placing,
# Nearest to hit: hits, hitting, airman, hb, midseason, nu, hakim, batted,
# Nearest to ocean: warm, atlantic, oceans, tropospheric, warmer, upwelling, intelsat, inmarsat,
# Nearest to additional: provided, tte, announced, added, eukaryotes, plasmid, voices, eccl,
# Nearest to governor: state, controlled, presides, laeken, fletcher, daerah, peripheral, announce,
# Nearest to proposed: proposal, prior, nomenclature, naming, enceladus, major, proposals, entice,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8223 0.0415 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8131 0.0398 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8901 0.0397 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8758 0.0397 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8543 0.0396 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8283 0.0400 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7224 0.0399 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8048 0.0397 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7055 0.0400 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8240 0.0392 sec/batch
# Nearest to also: of, and, a, is, with, for, include, which,
# Nearest to state: states, governor, bubi, mcgowan, knoxville, mississippi, kemp, kmaq,
# Nearest to s: the, and, in, two, nine, a, four, of,
# Nearest to have: are, been, has, some, most, for, that, as,
# Nearest to had: was, still, were, he, went, that, fell, never,
# Nearest to if: or, banach, leq, vx, arraignment, algebraically, declare, hom,
# Nearest to his: he, him, career, was, graduated, spent, soon, died,
# Nearest to between: with, of, the, and, southern, dominant, within, controlled,
# Nearest to nobel: prize, nagano, laureate, pond, astrophysicist, activist, prizes, basf,
# Nearest to account: malagasy, trillion, shelves, cra, dreadnoughts, michener, mlk, rebounded,
# Nearest to notes: octave, octaves, cantus, wikiquote, felling, citations, simulator, eis,
# Nearest to hit: hits, airman, hb, hitting, midseason, nu, trotskyism, hakim,
# Nearest to ocean: warm, tropospheric, oceans, intelsat, warmer, expedition, atlantic, broadcast,
# Nearest to additional: provided, announced, tte, added, showed, eccl, plasmid, eukaryotes,
# Nearest to governor: state, controlled, laeken, fletcher, hydrosphere, bustamante, peripheral, presides,
# Nearest to proposed: proposal, prior, nomenclature, naming, enceladus, proposals, faster, schmitt,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8206 0.0414 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7909 0.0398 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
